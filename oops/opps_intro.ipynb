# %% [markdown]
# #### Defination of OOP
# - object - oriented programing (OOP)
# - Is programing style / approch the organies code around rather than functions and logic. an object is self - contrained unit that contains both data  (attributes) and code (methods) that operates om that data.

# %%
account_num = "22F71A05B6"
account_holder = "Gowri"
balance = 3000
def deposit(amount):
    global balance
    balance += amount
    print(f"deposit :{amount}, balance : {balance}")

def withdraw(amount):
    global balance 
    if balance >= amount: 
        balance -= amount
        print("withdraw",amount,"new balance :" , balance)
    else:
        print("insuffient funds")
def check_balance():
    global balance
    print("Current balance :" , balance)

# %%
account_num1 = "22F71A05B6"
account_holder = "Gowri"
balance = 3000
deposit(1000)
withdraw(500)
check_balance()
# Out:
# deposite :1000, balance : 4000
# withdraw 500 new balance : 3500
# Current balance : 3500

# %%
account_num2 = "33F71A05B6"
account_holder = "swarna"
balance = 4000
deposit(1000)
withdraw(500)
check_balance()
# Out:
# deposite :1000, balance : 5000
# withdraw 500 new balance : 4500
# Current balance : 4500

# %%
account_num2 = "33FA05B6"
account_holder = "rna"
balance = 4000
deposit(1000)
withdraw(50000)
check_balance()
# Out:
# deposite :1000, balance : 5000
# insuffient funds
# Current balance : 5000

# %%
# same using oops . data and methods bunlded together
class BankAccount:
    #constructor method 
    def __init__(self,account_num,account_holder,balance):
        self.account_num = account_num
        self.account_holder = account_holder
        self.balance = balance

     #methods (functions inside a class)  
    def deposit (self, amount):
        self.balance += amount 
        print(f"deposited : {amount} , new balance : {self.balance}")
    def withdraw(self, amount):

        if self.balance >= amount: 
            self.balance -= amount
            print("withdraw",amount,"new balance :" , self.balance)
        else:
            print("insuffient funds")
    def check_balance(self):
        print(f"Current balance :{self.balance}")

# %%
account1 = BankAccount("a2345a","honey",5000)
account2 = BankAccount("b2345b","pinky",7000)

# %%
account1.deposit(1000)
# Out:
# deposited : 1000 , new balance : 6000

# %%
account1.withdraw(60)
# Out:
# withdraw 60 new balance : 5940

# %%
account1.check_balance()
# Out:
# Current balance :5940

# %%
account2.deposit(2000)
# Out:
# deposited : 2000 , new balance : 9000

# %%
account2.withdraw(600)
# Out:
# withdraw 600 new balance : 8340

# %%
account2.check_balance()
# Out:
# Current balance :8340
