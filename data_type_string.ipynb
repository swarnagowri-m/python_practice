# %% [markdown]
# ## What is a String ?
# - A String is a sequence of character (Letter, numbers , symbols) enclosed in quotes. " data"
# - It's used to represent text data in python.

# %%
# how to create a string
# you can create string using single quotes , double ,triple .

# %%
# Using single quotes 
names = 'Swarna'
# Using double quotes
named = "Gowri"

print(type(names))
print(type(named))
# Out:
# <class 'str'>
# <class 'str'>

# %%
type(names)
# Out:
# str

# %%
age = 30

# %%
type(age)
# Out:
# int

# %%
paragraph = ''' this a long paragraph 
it is usefull with long text 
to enter ....
'''

# %%
type(paragraph)
# Out:
# str

# %%
print(paragraph)
# Out:
#  this a long paragraph
# it is usefull with long text
# to enter ....

# %%
example = "swarna's pen is it"

# %%
print(example)
# Out:
# swarna's pen is it

# %% [markdown]
# ## Using f String (Formatted string)
# f-strings lets you embed variables inside a string easily

# %%
name = "Bhanu"

# %%
f"{name}'s book"
# Out:
# "Bhanu's book"

# %%
age =17

# %%
f"my name is{name} and my age is {age}"
# Out:
# 'my name isBhanu and my age is 17'

# %%
x = 10
y = 20
print(f"{x}+{y}= {x+y}")
# Out:
# 10+20= 30

# %% [markdown]
# ### key points for f string
# - Start the string gwith f"......{varaible}......", f'...........{varaible}.............'
# f'''...........{varaible}..........
# .................{varaible}....
# ...........'''
# - Use {} to insert variabe or expression

# %% [markdown]
# ### common operations and methods
# -String have a large number of build- in method for mainpulation string
# ### 1. concatenation (+) and Repetition (*)
# - '+' joins two strings togethers, creating a new string.
# - '*' Repeats a string a specified number of times (using an integer), creates new string.

# %%
a = "python"
b = "HTML"
a + " " + b
# Out:
# 'python HTML'

# %%
c = a + " : " + b
print(f"print the value inside the  c :{c}")
# Out:
# print the value inside the  c :python:HTML

# %%
# "welcome to Edukron's Data Engineer Course !"

# %%
course_name = "Data Enginner"
institute = "Edukron"
print(f"welcome to {institute}'s {course_name } Course !")
# Out:
# welcome to Edukron's Data Enginner !

# %%
print("welcome to "+ institute + "'s " + course_name +" course !" )
# Out:
# welcome to Edukron's Data Enginner course !

# %%
#Repeating a separator 
separator = " -*= " * 10
separator
# Out:
# ' -*=  -*=  -*=  -*=  -*=  -*=  -*=  -*=  -*=  -*= '

# %% [markdown]
# Input()
# - Function is used to take data from the user at runtime through they keyboard
# - what ever you pass through this input() function its in the string
#
# ### int()     #type casting
# - it is used to convert any integer which is in the form of string
#
# ### float()       # type casting
# - it is used to convert any float which is in the form of string

# %%
name = "Swarna"

# %%
name
# Out:
# 'Swarna'

# %%
name = input("Enter your name")

# %%
name
# Out:
# 'Bhanu'

# %%
age = input("enter a age")

# %%
age
# Out:
# '23'

# %%
age1 = int(input("Enter a number "))
age1
# Out:
# 89

# %%
type(age1)
# Out:
# int

# %%
height = float(input("enter a height"))
height
# Out:
# 56.7

# %%
type(height)
# Out:
# float

# %% [markdown]
# ### len()
# - this is built in function that returns the number of charaters (lenght)of a string

# %%
family = "Fruits"
apple = "lets eat one fruit daily "
health = "it make our health better"

# %%
family_lenghth =len(family)
family_lenghth
# Out:
# 6

# %%
apple_lenghth =len(apple)
apple_lenghth
# Out:
# 25

# %%
health_lenghth =len(health)
health_lenghth
# Out:
# 25

# %%
type(health_lenghth)
# Out:
# int

# %%
# length of a empty string
a =""
len(a)
# Out:
# 0

# %%
# lenght of string with spaces
b = "     "
len(b)
# Out:
# 5

# %%
# String with numbers, spaces  and special symobls
c = " agjjmn m !@#$E$% 12234567"
d = len(c)
print(d)
print(type(c))
# Out:
# 26
# <class 'str'>

# %%
family = "Fruits"
apple = "lets eat one fruit daily "
health = "it make our health better"

# %%
# Concationation
# length after concatioation 
e = family + apple
f = len(e)
print(f)
print(e)
# Out:
# 31
# Fruitslets eat one fruit daily

# %% [markdown]
# # Indexing ([]) and slicing ([:])
# - Indexing - Accessing a string character at a specific position (index). python 0 - based Indexing (first character is at index 0).
# - Negative Indexing count from the end (-1 is the last character)

# %%
name = "Swarna"
name[0]
# Out:
# 'S'

# %% [markdown]
# " S  w  a  r  n  a "
# [ 0  1  2  3  4  5]
# [-6 -5 -4 -3 -2 -1]

# %%
name[1]
# Out:
# 'w'

# %%
name[2]
# Out:
# 'a'

# %%
name[-1]
# Out:
# 'a'

# %%
health = "it make our health better"

# %%
# accesing 'm
health[3]
# Out:
# 'm'

# %% [markdown]
# ## slicing: ([start: stop : stop])
# - extracting portion (substring) of the string using
# ([start: stop : stop])
#   - start : The index where the slice begins (inclusive ) .  Default to 0
#   - stop : The index where the slice end (exclusive). Defaults to the end of the srting.
#   - step : The increment between indices . Defaults to 1

# %%
health = "it make our health better"
len(health)
# Out:
# 25

# %%
# Get the first 5 char of the health
health[0:6]
# Out:
# 'it mak'

# %%
health[0:7:2]
# Out:
# 'i ae'

# %%
health[:7]
# Out:
# 'it make'

# %%
health[:]
# Out:
# 'it make our health better'

# %%
health[-6:]
# Out:
# 'better'

# %%
health[-6:-1]
# Out:
# 'bette'

# %%
# step
name = "Swarna"
name[::2]
# Out:
# 'San'

# %%
# Reversing the string
name[::-1]
# Out:
# 'anrawS'

# %%
# String operation:
# String is inmutable
# concatation
#reverse
#indexing
#slicing
# split

# %% [markdown]
# # String methods str.lower() and str.upper()
# - lower() :Returns a new string with all characters converted to lower
#
# - upper() :Returns a new string with all characters converted to upper

# %%
family = "Fruits"
apple = "lets eat one fruit daily "
health = "it make our health better"

# %%
print(family)
family.upper()
# Out:
# Fruits
# 'FRUITS'

# %%
print(apple)
apple.upper()
# Out:
# lets eat one fruit daily
# 'LETS EAT ONE FRUIT DAILY '

# %%
print(apple)
apple.lower()
# Out:
# lets eat one fruit daily
# 'lets eat one fruit daily '

# %%
gender1 = "male"
gender2 = "Male"
gender3 = "MALE"

# %%
print(gender1)
print(gender2)
print(gender3)
# Out:
# male
# Male
# MALE

# %%
print(gender1.lower())
print(gender2.lower())
print(gender3.lower())
# Out:
# male
# male
# male

# %%
print(gender1.upper())
print(gender2.upper())
print(gender3.upper())

# %%
code ="22F71a05b6"
print(code.upper())
print(code.lower())
# Out:
# 22F71A05B6
# 22f71a05b6

# %%
first_name = "Swarna"
last_name = "Gowri"
full_name = first_name + " " +last_name
print(full_name)
print(" upper case : "+full_name.upper())
print("lower case : " +full_name.lower())
print(len(full_name))
# Out:
# Swarna Gowri
#  upper case : SWARNA GOWRI
# lower case : swarna gowri
# 12

# %% [markdown]
# ### str.strip()
# - it returns a new string with leading and trailing character removed .
#
# - if char is omitted or none , it removes whitespaces char
# - if char is given it removes any character in the char string from the end
# - by using this we can remove white spaces
#
#
# str.strip(['char'])
#
# str.lstrip() : starting chracter
#
# str.rstrip(): end character

# %%
name1 = "Swarna"
name2 = "  Swarna"
name3 = " Swarna "
name4 = "Swarna"

# %%
name1 == name2
# Out:
# False

# %%
name1.strip()
# Out:
# 'Swarna'

# %%
name2.strip()
# Out:
# 'Swarna'

# %%
#removing leading ("space at the start")/ trailing whitespaces ("sapce at the end")


name3 = " Swarna "
print(name3)
v = name3.strip()
print(v)
v
# Out:
#  Swarna
# Swarna
# 'Swarna'

# %%
leading_space = " Swarna "
print(leading_space)
left_strip = leading_space.lstrip()
left_strip
# Out:
#  Swarna
# 'Swarna '

# %%
leading_space = " Swarna "
print(leading_space)
r_strip = leading_space.rstrip()
r_strip
# Out:
#  Swarna
# ' Swarna'

# %%
# by removing any value 
leading_space = "==Swarna=="
print(leading_space)
r_strip = leading_space.rstrip("=")
r_strip
# Out:
# ==Swarna==
# '==Swarna'

# %%
# by removing any value 
leading_space = "==Swarna=="
print(leading_space)
l_strip = leading_space.lstrip("=")
l_strip
# Out:
# ==Swarna==
# 'Swarna=='

# %%
leading_space = "==Swarna=="
print(leading_space)
l_strip = leading_space.lstrip("=").rstrip("=")
l_strip
# Out:
# ==Swarna==
# 'Swarna'

# %%
name = "Swarna Gowri"
name.lstrip("Swarna")
# Out:
# ' Gowri'

# %%
name = "Swarna Gowri"
name.lstrip("a")
# doesnot works
# Out:
# 'Swarna Gowri'

# %%
name = "Swarna Gowri"
name.strip("Swarna ri")
# Out:
# 'Go'

# %% [markdown]
# ### str.replace(old, new[count])

# %%
course_slogan = "learn Data Engineering with real_time projects"
tech_stack = "Azure DevOps and Python and java"

# %%
# Replace  "data engineering" with "data science"
new_slogan = course_slogan.replace("Data Engineering","Data Science")
print(course_slogan)
print(new_slogan)
# Out:
# learn Data Engineering with real_time projects
# learn Data Science with real_time projects

# %%
# this process is called chaing  -.replace(" "," _").lower()
r_slogan = course_slogan.replace(" "," _").lower()
print(course_slogan)
print(r_slogan)
# Out:
# learn Data Engineering with real_time projects
# learn _data _engineering _with _real_time _projects

# %%
#count
tech_stack = "Azure DevOps and Python and java"

# %%
new_s = tech_stack.replace("and", "&")
new_s
# Out:
# 'Azure DevOps & Python & java'

# %%
new_s = tech_stack.replace("and", "&",1)
new_s
# Out:
# 'Azure DevOps & Python and java'

# %%
course_slogan = "learn Data Engineering with real_time projects"
course_slogan.replace(" ","")
# Out:
# 'learnDataEngineeringwithreal_timeprojects'

# %%
course_slogan = "learn Data Engineering with real_time projects"
course_slogan.replace(" ","").lower()
# Out:
# 'learndataengineeringwithreal_timeprojects'

# %% [markdown]
# # split
#
# str.split(sep=None, maxsplit=-1)
#
# Explanation: Returns a list of substrings (words) by splitting the string at occurrences of the separator sep.
#
# - If sep is omitted or None, splits by any whitespace character and discards empty strings.
# - If sep is specified, splits exactly at that separator.
# - maxsplit: If specified, performs at most maxsplit splits (resulting in maxsplit + 1 elements in the list). The remainder of the string is the last element

# %%
course_slogan = "learn Data Engineering with real_time projects"

# %%
# splitting slogan by white spaces ( default)
words = course_slogan.split()
words
# Out:
# ['learn', 'Data', 'Engineering', 'with', 'real_time', 'projects']

# %%
#splitting tech_stack by comma
tech_stack = "Azure,DevOps,and,Python,and,java"
word = tech_stack.split(',')
print(word)
len(word)
# Out:
# ['Azure', 'DevOps', 'and', 'Python', 'and', 'java']
# 6

# %%
#splitting with the character 
name = "Swarna"
name.split('a')
# Out:
# ['Sw', 'rn', '']

# %%
#Specify number of splits we want
tech_stack = "Azure,DevOps,and,Python,and,java"
word = tech_stack.split(',',maxsplit=2)
print(word)
len(word)
# Out:
# ['Azure', 'DevOps', 'and,Python,and,java']
# 3
